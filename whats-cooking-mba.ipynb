# %% [markdown]
# # Predicting cuisine by provided ingredients

# %% [markdown]
# Goal is to use provided recipe ingredients to classify the cuisine

# %% [markdown]
# ## Part 1: Exploratory analysis

# %%
import pandas as pd
import os
import json
import string
import math
import itertools

# %% [markdown]
# Loading of whats-cooking dataset

# %%
curr_path = os.path.dirname(os.getcwd())
data_path = os.path.join(curr_path, 'whats-cooking\\data')
input_file = os.path.join(data_path, 'train.json')

# %%
with open(input_file) as file:
    data = json.load(file)
    df = pd.DataFrame(data)

# %%
cuisine_counts = dict(df['cuisine'].value_counts())

# %%
from collections import Counter

counters = {}
for cuis in cuisine_counts.keys():
    counters[cuis] = Counter()
    indices = (df['cuisine'] == cuis)
    for ingr in df[indices]['ingredients']:
        counters[cuis].update(ingr)

# %%
counters['italian']
# Out:
# Counter({'sugar': 760,
#          'pistachio nuts': 7,
#          'white almond bark': 1,
#          'flour': 142,
#          'vanilla extract': 219,
#          'olive oil': 3111,
#          'almond extract': 56,
#          'eggs': 627,
#          'baking powder': 186,
#          'dried cranberries': 8,
#          'chopped tomatoes': 37,
#          'fresh basil': 787,
#          'garlic': 1471,
#          'extra-virgin olive oil': 1362,
#          'kosher salt': 656,
#          'flat leaf parsley': 588,
#          'pimentos': 16,
#          'sweet pepper': 7,
#          'dried oregano': 626,
#          'sharp cheddar cheese': 9,
#          'pepper': 965,
#          'swiss cheese': 7,
#          'provolone cheese': 138,
#          'canola oil': 41,
#          'mushrooms': 184,
#          'black olives': 67,
#          'sausages': 58,
#          'Italian parsley leaves': 74,
#          'walnuts': 38,
#          'hot red pepper flakes': 76,
#          'fresh lemon juice': 471,
#          'trout fillet': 3,
#          'garlic cloves': 1619,
#          'chipotle chile': 2,
#          'fine sea salt': 77,
#          'fresh parmesan cheese': 251,
#          'butter': 1030,
#          'all-purpose flour': 918,
#          'fat free less sodium chicken broth': 158,
#          'chopped fresh chives': 68,
#          'gruyere cheese': 18,
#          'ground black pepper': 1444,
#          'bacon slices': 48,
#          'gnocchi': 41,
#          'fat free milk': 42,
#          'cooking spray': 491,
#          'salt': 3454,
#          'italian seasoning': 347,
#          'broiler-fryer chicken': 1,
#          'mayonaise': 63,
#          'zesty italian dressing': 11,
#          'marinara sauce': 222,
#          'linguine': 193,
#          'capers': 306,
#          'crushed red pepper flakes': 179,
#          'olives': 29,
#          'lemon zest': 98,
#          'sliced mushrooms': 131,
#          'sherry': 13,
#          'grated parmesan cheese': 1580,
#          'heavy cream': 300,
#          'spaghetti': 296,
#          'chicken broth': 245,
#          'cooked chicken': 33,
#          'yellow corn meal': 64,
#          'boiling water': 63,
#          'sea salt': 202,
#          'onions': 1240,
#          'crushed garlic': 20,
#          'green onions': 144,
#          'white sugar': 231,
#          'dried basil': 425,
#          'diced tomatoes': 429,
#          'bread slices': 15,
#          'great northern beans': 21,
#          'shrimp': 59,
#          'sage leaves': 89,
#          'Oscar Mayer Deli Fresh Smoked Ham': 1,
#          'hoagie rolls': 8,
#          'salami': 41,
#          'giardiniera': 5,
#          'mozzarella cheese': 396,
#          'pepperoni': 48,
#          'bay leaves': 107,
#          'crushed red pepper': 418,
#          'mussels': 38,
#          'basil': 174,
#          'black pepper': 636,
#          'dry white wine': 658,
#          'tomatoes': 601,
#          'finely chopped onion': 145,
#          'lemon': 236,
#          'pesto': 113,
#          'salmon fillets': 11,
#          'white wine': 176,
#          'pizza crust': 36,
#          'plum tomatoes': 340,
#          'part-skim mozzarella cheese': 201,
#          'crushed tomatoes': 241,
#          'fresh rosemary': 292,
#          'boneless pork loin': 9,
#          'pappardelle': 11,
#          'red pepper': 49,
#          'Italian bread': 89,
#          'balsamic vinegar': 348,
#          'sausage casings': 78,
#          'honey': 126,
#          'shredded mozzarella cheese': 413,
#          'roasted red peppers': 114,
#          'penne pasta': 146,
#          'spinach': 119,
#          'asiago': 72,
#          'whole wheat pasta': 13,
#          'sweet onion': 69,
#          'grape tomatoes': 98,
#          'chestnuts': 9,
#          'granulated sugar': 82,
#          'whole milk ricotta cheese': 47,
#          'coffee ice cream': 3,
#          'large eggs': 625,
#          'mascarpone': 124,
#          'rum': 12,
#          'powdered sugar': 69,
#          'semisweet chocolate': 46,
#          'chestnut flour': 1,
#          'starchy potatoes': 2,
#          'grated nutmeg': 64,
#          'blood orange': 5,
#          'freshly ground pepper': 316,
#          'fennel bulb': 103,
#          'low salt chicken broth': 138,
#          'dijon mustard': 99,
#          'corn starch': 83,
#          'white wine vinegar': 73,
#          'tomato sauce': 357,
#          'shredded carrots': 11,
#          'english muffins, split and toasted': 2,
#          'chopped onion': 327,
#          'vegetable oil cooking spray': 73,
#          'chopped green bell pepper': 39,
#          'cheddar cheese': 18,
#          'lasagna noodles': 196,
#          'ranch dressing': 5,
#          'evaporated milk': 13,
#          'fresh parsley': 631,
#          'fresh oregano': 209,
#          'cold water': 58,
#          'chocolate morsels': 4,
#          'cream sweeten whip': 3,
#          'instant espresso granules': 4,
#          'whipping cream': 162,
#          'kahlĂşa': 12,
#          'chocolate covered coffee beans': 1,
#          'unflavored gelatin': 48,
#          'pound cake': 7,
#          'pinenuts': 252,
#          'zucchini': 326,
#          'baby carrots': 15,
#          'fresh basil leaves': 352,
#          'asparagus spears': 24,
#          'white onion': 48,
#          'carrots': 379,
#          'frozen peas': 67,
#          'arborio rice': 261,
#          'yellow crookneck squash': 3,
#          'fresh leav spinach': 25,
#          'cheese tortellini': 53,
#          'cherry tomatoes': 170,
#          'navy beans': 8,
#          'pecorino romano cheese': 146,
#          'fresh fava bean': 12,
#          'italian sausage': 129,
#          'large garlic cloves': 293,
#          'pasta sheets': 9,
#          'water': 1052,
#          'Turkish bay leaves': 3,
#          'dried chickpeas': 1,
#          'celery ribs': 130,
#          'semolina': 14,
#          'warm water': 182,
#          'vine ripened tomatoes': 12,
#          'bittersweet chocolate': 42,
#          'fat free yogurt': 4,
#          'skim milk': 16,
#          'angel food cake': 4,
#          'unsweetened cocoa powder': 84,
#          'instant espresso': 7,
#          'garlic salt': 61,
#          'tomato paste': 376,
#          'veal cutlets': 18,
#          'broccoli rabe': 47,
#          'whole milk': 157,
#          'parmigiano reggiano cheese': 306,
#          'dry bread crumbs': 115,
#          'fontina': 27,
#          'unsalted butter': 564,
#          'pasta sauce': 246,
#          'olive oil flavored cooking spray': 29,
#          'frozen chopped spinach': 131,
#          'large egg whites': 138,
#          'part-skim ricotta cheese': 111,
#          'manicotti shells': 18,
#          'fettucine': 136,
#          'parmesan cheese': 474,
#          'large shrimp': 77,
#          'chicken bouillon': 10,
#          'cream of tartar': 9,
#          'orange liqueur': 15,
#          'heavy whipping cream': 73,
#          'semi-sweet chocolate morsels': 21,
#          'cake flour': 24,
#          'confectioners sugar': 94,
#          'ground cinnamon': 85,
#          'ricotta cheese': 333,
#          'cream cheese': 105,
#          'dried porcini mushrooms': 81,
#          'chopped fresh thyme': 151,
#          'beef rib short': 5,
#          'dry red wine': 131,
#          'hot water': 85,
#          'fat free less sodium beef broth': 7,
#          'cremini mushrooms': 67,
#          'pitted kalamata olives': 94,
#          'cauliflower': 34,
#          'whole peeled tomatoes': 60,
#          'swiss chard': 63,
#          'banana squash': 1,
#          'vegetable broth': 81,
#          'bay leaf': 130,
#          'cannellini beans': 161,
#          'boneless skinless chicken breast halves': 182,
#          'light sour cream': 5,
#          'fava beans': 13,
#          'finely chopped fresh parsley': 33,
#          'fresh tarragon': 33,
#          'grated lemon zest': 142,
#          'chopped almonds': 12,
#          'broccoli': 64,
#          'potatoes': 59,
#          'self rising flour': 1,
#          'eggplant': 204,
#          'chicken': 84,
#          'pitas': 5,
#          'goat cheese': 92,
#          'reduced fat milk': 29,
#          'smoked trout': 1,
#          'fresh dill': 16,
#          'asparagus': 123,
#          'oil': 92,
#          'ricotta salata': 22,
#          'pecorino cheese': 52,
#          'grana padano': 7,
#          'pasta': 255,
#          'cracked black pepper': 117,
#          'green bell pepper': 163,
#          'vidalia onion': 19,
#          'smoked gouda': 14,
#          'baby spinach leaves': 39,
#          'shredded sharp cheddar cheese': 17,
#          'small red potato': 13,
#          'BertolliÂ® Classico Olive Oil': 16,
#          'bacon, crisp-cooked and crumbled': 2,
#          'bertolli vineyard premium collect marinara with burgundi wine sauc': 5,
#          'bread crumb fresh': 74,
#          '(    oz.) tomato sauce': 7,
#          'ground veal': 35,
#          'italian seasoning mix': 1,
#          'beef': 22,
#          'fat skimmed chicken broth': 28,
#          'solid pack pumpkin': 4,
#          'ground nutmeg': 127,
#          'white rice': 11,
#          'ground pepper': 77,
#          'fresh thyme leaves': 53,
#          'pistachios': 10,
#          'dried cherry': 6,
#          'prosciutto': 256,
#          'romano cheese': 89,
#          'parsley leaves': 23,
#          'shallots': 316,
#          'fresh raspberries': 14,
#          'dry vermouth': 18,
#          'canned low sodium chicken broth': 46,
#          'chicken livers': 14,
#          'raisins': 39,
#          'seasoned bread crumbs': 71,
#          'minced garlic': 334,
#          'half & half': 89,
#          'ground beef': 237,
#          'jack cheese': 9,
#          'vegetables': 29,
#          'lemon juice': 216,
#          'ricotta': 95,
#          'yellow onion': 153,
#          'reduced sodium chicken broth': 36,
#          'chopped fresh mint': 54,
#          'purple onion': 350,
#          'low sodium chicken broth': 78,
#          'polenta': 132,
#          'bell pepper': 38,
#          'olive oil cooking spray': 13,
#          'bacon': 124,
#          'egg yolks': 82,
#          'duck breast halves': 1,
#          'fennel seeds': 114,
#          'roma tomatoes': 44,
#          'pesto sauce': 26,
#          'arugula': 125,
#          'summer squash': 9,
#          'red wine vinegar': 227,
#          'ciabatta': 21,
#          'juice': 72,
#          'fresh herbs': 14,
#          'grated lemon peel': 89,
#          'dough': 46,
#          'coarse sea salt': 17,
#          'rosemary leaves': 10,
#          'red pepper flakes': 206,
#          'brie cheese': 14,
#          'cheese ravioli': 18,
#          'Italian seasoned breadcrumbs': 23,
#          'cheese': 127,
#          'parsley': 95,
#          'fat-free cottage cheese': 11,
#          'oven-ready lasagna noodles': 43,
#          'margarine': 38,
#          'radicchio': 40,
#          'garbanzo beans': 18,
#          'orzo pasta': 16,
#          'rubbed sage': 17,
#          'dried rosemary': 96,
#          'canned beef broth': 4,
#          'kale leaves': 7,
#          'chicken noodle soup': 1,
#          'italian style rolls': 1,
#          'genoa salami': 22,
#          'oregano': 114,
#          'boiled ham': 1,
#          'capicola': 4,
#          'iceberg lettuce': 6,
#          'jalapeno chilies': 20,
#          'diced celery': 15,
#          'italian salad dressing mix': 7,
#          'chopped cilantro fresh': 25,
#          'cider vinegar': 14,
#          'red bell pepper': 354,
#          'sliced green onions': 40,
#          'barbecue sauce': 9,
#          'prepared pizza crust': 2,
#          'boneless skinless chicken breasts': 132,
#          'SargentoÂ® Traditional Cut Shredded Mozzarella Cheese': 1,
#          'vegetable oil': 253,
#          'basil pesto sauce': 33,
#          'aioli': 3,
#          'cooked shrimp': 11,
#          'mozzarella balls': 4,
#          'sun-dried tomatoes': 118,
#          'milk': 277,
#          'condensed cream of mushroom soup': 16,
#          'fettuccine pasta': 24,
#          'frozen spinach': 24,
#          'lasagne': 6,
#          'passata': 3,
#          'fat free cream cheese': 8,
#          'french bread': 54,
#          'non-fat sour cream': 14,
#          'reduced fat swiss cheese': 3,
#          'fat-free mayonnaise': 8,
#          'roasted garlic': 7,
#          'seasoning': 12,
#          'kale': 58,
#          'sundried tomato paste': 4,
#          'dried thyme': 145,
#          'porcini': 7,
#          'fresh thyme': 62,
#          'sourdough loaf': 4,
#          'crust': 3,
#          'duck fat': 1,
#          'squabs': 1,
#          'confit': 2,
#          'aged gouda': 1,
#          'soppressata': 16,
#          'artichokes': 44,
#          'anchovy fillets': 124,
#          'lemon slices': 12,
#          'chicken cutlets': 23,
#          'saffron threads': 28,
#          'orzo': 51,
#          'veal chops': 4,
#          'oil cured olives': 3,
#          'pasta rotel': 2,
#          'pasta water': 10,
#          'cooking wine': 3,
#          'crusty bread': 10,
#          'fresh tomatoes': 32,
#          'uncooked rigatoni': 6,
#          'grating cheese': 6,
#          'vegetable stock': 29,
#          'freshly grated parmesan': 87,
#          'florets': 15,
#          'sliced almonds': 37,
#          'thyme sprigs': 45,
#          'egg whites': 95,
#          'greek yogurt': 6,
#          'penne': 99,
#          'fish fillets': 10,
#          'russet potatoes': 40,
#          'crumbled gorgonzola': 29,
#          'fontina cheese': 84,
#          'spinach leaves': 25,
#          'orange': 38,
#          'lamb shanks': 11,
#          'clove': 19,
#          'rosemary sprigs': 50,
#          'italian eggplant': 7,
#          'Sicilian olives': 7,
#          'mint sprigs': 28,
#          'peasant bread': 7,
#          'garlic powder': 252,
#          'Kraft Grated Parmesan Cheese': 10,
#          'peas': 42,
#          'Oscar Mayer Bacon': 1,
#          'Philadelphia Cream Cheese': 9,
#          'garnish': 3,
#          'dried navy beans': 5,
#          'celery': 155,
#          'diced onions': 42,
#          'wheat berries': 4,
#          'parsley sprigs': 38,
#          'thyme': 51,
#          'polenta prepar': 5,
#          'chicken breast halves': 35,
#          'dry sherry': 22,
#          'cocoa powder': 9,
#          'dried parsley': 90,
#          'chopped garlic': 69,
#          'baking soda': 68,
#          'coarse salt': 128,
#          'rigatoni': 60,
#          'nutmeg': 40,
#          'artichoke hearts': 99,
#          'pancetta': 153,
#          'parsnips': 7,
#          'whole wheat fettuccine': 4,
#          'ground sirloin': 20,
#          'red wine': 99,
#          'fresh marjoram': 29,
#          'castellane': 2,
#          'hot Italian sausages': 39,
#          'jumbo pasta shells': 37,
#          'fresh spinach': 87,
#          'chicken breasts': 93,
#          'gluten free blend': 1,
#          'paprika': 76,
#          'salt and ground black pepper': 66,
#          'bone in skinless chicken thigh': 1,
#          'figs': 10,
#          'egg substitute': 26,
#          'hot sauce': 20,
#          'ham': 42,
#          'balsamic vinaigrette': 6,
#          'pitted olives': 15,
#          'fresh chives': 24,
#          'white mushrooms': 20,
#          'haricots verts': 4,
#          'fresh peas': 16,
#          'bow-tie pasta': 86,
#          'asparagus tips': 3,
#          'green beans': 70,
#          'low-fat cottage cheese': 14,
#          'whole wheat lasagna noodles': 8,
#          'shredded parmesan cheese': 38,
#          'apricots': 5,
#          'grappa': 9,
#          'all purpose unbleached flour': 68,
#          'dry yeast': 71,
#          'worcestershire sauce': 54,
#          'amaretti': 6,
#          'frozen strawberries': 1,
#          'strawberries': 48,
#          'cooked ham': 9,
#          'Alfredo sauce': 43,
#          'chopped fresh sage': 91,
#          'cheese slices': 11,
#          'bread': 51,
#          'morel': 2,
#          'leeks': 106,
#          '1% low-fat cottage cheese': 10,
#          'feta cheese crumbles': 68,
#          'pork belly': 2,
#          'fresh sage': 29,
#          'pork loin': 3,
#          'sliced black olives': 49,
#          'medium shrimp': 70,
#          'red chili peppers': 22,
#          'parmigiano-reggiano cheese': 53,
#          'fresh mint': 53,
#          'baguette': 119,
#          'chicken legs': 7,
#          'baby spinach': 117,
#          'white beans': 38,
#          'ground pork': 72,
#          'romana': 1,
#          'fresh mushrooms': 117,
#          'crimini mushrooms': 26,
#          'navel oranges': 10,
#          'kalamata': 62,
#          'sea scallops': 31,
#          'ladyfingers': 40,
#          'reduced fat cream cheese': 3,
#          'whipped topping': 12,
#          'wine': 15,
#          'frozen broccoli': 5,
#          'nonfat ricotta cheese': 32,
#          'shells': 8,
#          'reduced-fat cheese': 1,
#          'cornflake cereal': 2,
#          'beef brisket': 2,
#          'dry pasta': 8,
#          'white bread': 35,
#          'pork': 10,
#          'sweet italian sausage': 72,
#          'prosecco': 10,
#          'bread dough': 16,
#          'baby lima beans': 3,
#          'whipped cream': 15,
#          'hot cocoa mix': 2,
#          'brewed coffee': 18,
#          'abbamele': 1,
#          'wild mushrooms': 30,
#          'chopped walnuts': 46,
#          'fregola': 4,
#          'savoy cabbage': 10,
#          'mushroom caps': 17,
#          'pinot grigio': 3,
#          'liquid egg substitute': 1,
#          'chocolate candy bars': 5,
#          'cooked rice': 5,
#          'bread crumbs': 103,
#          'banana peppers': 5,
#          'toasted walnuts': 7,
#          'dark rum': 22,
#          'dried fig': 11,
#          'chopped parsley': 99,
#          'ground white pepper': 33,
#          "soft goat's cheese": 10,
#          'truffle oil': 17,
#          'hazelnuts': 53,
#          'veal scallopini': 2,
#          'elbow macaroni': 19,
#          'bread flour': 77,
#          'bread yeast': 1,
#          'red potato': 26,
#          'vegan parmesan cheese': 4,
#          'ahi': 1,
#          'golden brown sugar': 14,
#          'anjou pears': 3,
#          'granny smith apples': 6,
#          'crystallized ginger': 10,
#          'ice water': 7,
#          'vegetable shortening': 5,
#          'chinese five-spice powder': 1,
#          'whole wheat flour': 21,
#          'large egg yolks': 142,
#          'lean ground beef': 135,
#          'sausage links': 32,
#          'pork chops': 8,
#          'rosemary': 57,
#          'nectarines': 5,
#          'sweet cherries': 12,
#          'orange zest': 28,
#          'lavender buds': 1,
#          'apricot halves': 4,
#          'diced tomatoes in juice': 7,
#          'scallions': 61,
#          'italian salad dressing': 41,
#          'short pasta': 7,
#          'lemon wedge': 58,
#          'porterhouse steaks': 4,
#          '1% low-fat milk': 68,
#          'golden raisins': 46,
#          'cinnamon sticks': 18,
#          'broccolini': 3,
#          'salted butter': 11,
#          'chicken stock': 142,
#          'coffee granules': 12,
#          'lemon rind': 34,
#          'baby portobello mushrooms': 10,
#          'broccoli florets': 64,
#          'orecchiette': 41,
#          'melted butter': 24,
#          'pizza shells': 3,
#          'frozen mixed thawed vegetables,': 2,
#          'ragu old world style pasta sauc': 11,
#          'loosely packed fresh basil leaves': 21,
#          'whole wheat spaghetti': 22,
#          'butternut squash': 62,
#          'wonton wrappers': 17,
#          'meat': 15,
#          'pear tomatoes': 6,
#          'gaeta olives': 5,
#          'yukon gold potatoes': 39,
#          'turbot': 2,
#          'ground lamb': 6,
#          'refrigerated pizza dough': 31,
#          'potato gnocchi': 20,
#          'cream': 27,
#          'angel hair': 60,
#          'lime juice': 6,
#          'gelato': 4,
#          'cherry preserves': 2,
#          'amaretto liqueur': 4,
#          'cherries': 14,
#          'instant espresso powder': 22,
#          'nuts': 3,
#          'brown sugar': 67,
#          'pie shell': 2,
#          'marsala wine': 105,
#          'basil leaves': 153,
#          'cake': 7,
#          'crabmeat': 11,
#          'chopped fresh herbs': 8,
#          'button mushrooms': 35,
#          'escarole': 47,
#          'chopped pecans': 28,
#          'chocolate bars': 2,
#          'coffee liqueur': 11,
#          'flat anchovy': 5,
#          'italian loaf': 4,
#          'salad dressing': 23,
#          'pitted black olives': 24,
#          'rotini': 46,
#          'frozen mixed vegetables': 4,
#          'canned tomatoes': 26,
#          'feta cheese': 36,
#          'anise seed': 13,
#          'top sirloin': 1,
#          'candy': 3,
#          'angel food cake mix': 2,
#          'buttercream frosting': 1,
#          'sour cream': 71,
#          'shredded cheddar cheese': 42,
#          'cottage cheese': 44,
#          'noodles': 38,
#          'lime': 5,
#          'watermelon': 5,
#          'risotto': 11,
#          'ice cubes': 8,
#          'peeled tomatoes': 32,
#          'cooked vermicelli': 5,
#          'buns': 1,
#          'apple cider vinegar': 7,
#          'ground red pepper': 34,
#          'yellow bell pepper': 85,
#          'active dry yeast': 128,
#          'baking potatoes': 34,
#          'grated romano cheese': 19,
#          'quinoa': 8,
#          'littleneck clams': 26,
#          'whole wheat bread': 8,
#          'cream cheese, soften': 40,
#          'salad seasoning mix': 4,
#          'cucumber': 25,
#          'pappardelle pasta': 6,
#          'fresh mozzarella': 95,
#          'tuna steaks': 16,
#          'shredded zucchini': 4,
#          'dried pasta': 13,
#          'berries': 5,
#          'clams': 50,
#          'ground round': 25,
#          'fettuccine, cook and drain': 4,
#          'tomato purĂ©e': 47,
#          'chopped celery': 103,
#          'ditalini pasta': 15,
#          'lobster': 11,
#          'almonds': 35,
#          'anise': 13,
#          'anise extract': 12,
#          'brandy': 25,
#          'boneless chicken breast': 19,
#          'buffalo sauce': 2,
#          'blue cheese dressing': 3,
#          'cannelloni shells': 2,
#          'butter cooking spray': 3,
#          'light alfredo sauce': 7,
#          'rice': 12,
#          'cream of chicken soup': 9,
#          'chees fresh mozzarella': 72,
#          'shrimp tails': 2,
#          'bay scallops': 12,
#          'lump crab meat': 17,
#          'fish stock': 11,
#          'capellini': 8,
#          'veal': 17,
#          'beef stock': 24,
#          'chard': 3,
#          'grated GruyĂ¨re cheese': 5,
#          'panko': 25,
#          'chickpeas': 37,
#          'white cornmeal': 4,
#          'red bell pepper, sliced': 2,
#          'herbs': 20,
#          'chicken thighs': 32,
#          'green bell pepper, slice': 13,
#          'vanilla': 28,
#          'liqueur': 10,
#          'aged balsamic vinegar': 8,
#          'limoncello': 6,
#          'golden beets': 4,
#          'pizza doughs': 103,
#          'black cod': 2,
#          'green cabbage': 12,
#          'cavolo nero': 4,
#          'winter squash': 1,
#          'thin pizza crust': 9,
#          'toasted pine nuts': 30,
#          'grated parmesan romano': 2,
#          'cumin seed': 4,
#          'cilantro leaves': 7,
#          'seasoning salt': 15,
#          'mixed greens': 16,
#          'turkey breast cutlets': 9,
#          'cod fillets': 8,
#          'barilla': 4,
#          'linguini': 9,
#          'perciatelli': 7,
#          'crumbled blue cheese': 16,
#          'black mission figs': 4,
#          'swordfish steaks': 11,
#          'anchovy paste': 47,
#          'chuck': 8,
#          'tomatoes with juice': 30,
#          'store bought low sodium chicken stock': 2,
#          'fresh lavender': 1,
#          'grated orange': 31,
#          'vanilla wafers': 3,
#          'amaretto': 19,
#          'toasted almonds': 6,
#          'light corn syrup': 8,
#          'focaccia': 10,
#          'oyster mushrooms': 6,
#          'shiitake mushroom caps': 16,
#          'onion powder': 39,
#          'sourdough': 7,
#          'orange bell pepper': 27,
#          'nonfat cottage cheese': 6,
#          'stewed tomatoes': 37,
#          'raspberries': 25,
#          'vanilla beans': 26,
#          'Frangelico': 9,
#          'vegetable oil spray': 22,
#          'table salt': 21,
#          'white peppercorns': 2,
#          'herb vinegar': 3,
#          'reduced fat sharp cheddar cheese': 8,
#          'deli ham': 4,
#          'ground turkey': 48,
#          'hot dogs': 2,
#          'italian style stewed tomatoes': 15,
#          'veal stock': 7,
#          'portabello mushroom': 41,
#          'rocket leaves': 35,
#          'country bread': 26,
#          'bottled balsamic vinaigrette': 1,
#          'scallops': 12,
#          'italian tomatoes': 16,
#          'peeled shrimp': 3,
#          'whole wheat pizza crust': 3,
#          'dried mixed herbs': 3,
#          'whole wheat pastry flour': 6,
#          'nonstick spray': 7,
#          'low-fat sour cream': 8,
#          'day old bread': 2,
#          'champagne vinegar': 9,
#          'pizza sauce': 71,
#          'red vermouth': 5,
#          'low sodium chicken stock': 6,
#          'peppercorns': 3,
#          'turkey stock': 3,
#          'cooked turkey': 6,
#          'green olives': 52,
#          'spaghettini': 23,
#          'minced onion': 41,
#          'beef broth': 62,
#          'dried mint flakes': 3,
#          'ravioli': 16,
#          'meat loaf mix': 1,
#          'rub': 2,
#          'clam juice': 26,
#          'bottled clam juice': 15,
#          'cayenne pepper': 50,
#          'pears': 19,
#          'gorgonzola': 27,
#          'duck': 2,
#          'pure vanilla extract': 22,
#          'panettone': 4,
#          'sambuca': 4,
#          'light brown sugar': 15,
#          'fat free frozen top whip': 5,
#          'frozen bread dough': 9,
#          'whole wheat breadcrumbs': 10,
#          'ground chuck': 16,
#          'bows': 3,
#          'sauce': 53,
#          'ground oregano': 4,
#          'lean ground turkey': 2,
#          'milk chocolate': 11,
#          'hazelnut butter': 4,
#          'fig jam': 2,
#          'crackers': 7,
#          'sun-dried tomatoes in oil': 28,
#          'dark chocolate': 7,
#          'vanilla ice cream': 17,
#          'chives': 31,
#          'radishes': 13,
#          'lettuce': 6,
#          'grilled chicken': 2,
#          'flatbread': 4,
#          'fresh parsley leaves': 56,
#          'lemon extract': 7,
#          'salad greens': 11,
#          'brown rice': 6,
#          'tortellini': 19,
#          'reduced fat alfredo sauce': 4,
#          'fresh asparagus': 24,
#          'round steaks': 5,
#          'chili powder': 26,
#          'ground cumin': 30,
#          'rolls': 21,
#          'prego traditional italian sauce': 4,
#          'brown hash potato': 5,
#          'nonfat milk': 7,
#          'frozen cheese ravioli': 6,
#          'mild Italian sausage': 17,
#          'sandwich rolls': 3,
#          'orange juice concentrate': 5,
#          'rotelle': 3,
#          'sweet italian sausag links, cut into': 2,
#          'idaho potatoes': 4,
#          'popcorn': 1,
#          'grated orange peel': 26,
#          'french fried onions': 1,
#          'turbinado': 7,
#          'cooked chicken breasts': 16,
#          'farro': 14,
#          'flour tortillas': 11,
#          'english cucumber': 7,
#          'minced peperoncini': 2,
#          'teleme': 2,
#          'brine cured green olives': 4,
#          'black forest ham': 1,
#          'frozen whole kernel corn': 5,
#          'sweet potatoes': 15,
#          'applewood smoked bacon': 7,
#          'panko breadcrumbs': 24,
#          'coarse kosher salt': 9,
#          'cornmeal': 72,
#          'dried sage': 28,
#          'dri leav thyme': 6,
#          'low sodium beef broth': 3,
#          'cabbage': 12,
#          'fresh shiitake mushrooms': 15,
#          'rabbit': 8,
#          'herbes de provence': 12,
#          'dressing': 7,
#          'chicken fingers': 3,
#          'reduced-fat sour cream': 13,
#          'dried fettuccine': 14,
#          'white pepper': 22,
#          'albacore tuna in water': 5,
#          'light mayonnaise': 7,
#          'turkey tenderloins': 4,
#          'almond flour': 8,
#          'raw almond': 3,
#          'fresh orange juice': 32,
#          'cranberries': 3,
#          'orange marmalade': 6,
#          'fresh lemon': 4,
#          'condensed chicken broth': 1,
#          'oil packed anchovy fillets': 3,
#          'boneless chicken skinless thigh': 20,
#          'sugar pea': 16,
#          'nonfat yogurt': 4,
#          'roast red peppers, drain': 24,
#          'french baguette': 25,
#          'ripe olives': 26,
#          'honey glazed ham': 2,
#          'chiles': 9,
#          'spring onions': 3,
#          'candied orange peel': 13,
#          'lard': 5,
#          'cinnamon': 23,
#          'semolina flour': 32,
#          'onion salt': 2,
#          'beef demi-glace': 1,
#          'veal shanks': 21,
#          'orange peel': 7,
#          'lemon peel': 11,
#          'plain yogurt': 7,
#          'Quinoa Flour': 1,
#          'spelt flour': 2,
#          'plums': 14,
#          'heirloom tomatoes': 21,
#          'fresh lime juice': 25,
#          'artichok heart marin': 33,
#          'bucatini': 16,
#          'processed cheese': 5,
#          'egg noodles, cooked and drained': 3,
#          'tapioca flour': 1,
#          'lasagna noodles, cooked and drained': 26,
#          'firm tofu': 9,
#          'sherry vinegar': 27,
#          'country style bread': 7,
#          'teardrop tomatoes': 2,
#          'ground sausage': 5,
#          'pita pockets': 1,
#          'orange juice': 19,
#          'chili pepper': 5,
#          'currant': 7,
#          'small capers, rins and drain': 2,
#          'filet': 4,
#          'lettuce leaves': 8,
#          'vodka': 27,
#          'stolichnaya': 1,
#          'romaine lettuce': 33,
#          'croutons': 18,
#          'pepperocini': 2,
#          'cherry peppers': 3,
#          'dandelion': 1,
#          'beans': 6,
#          'hot pepper sauce': 7,
#          'shredded Monterey Jack cheese': 13,
#          'cane sugar': 1,
#          'mixed nuts': 1,
#          'meatballs': 17,
#          'plain dry bread crumb': 11,
#          'spanish onion': 9,
#          'cuban peppers': 3,
#          'green tomatoes': 2,
#          'sesame seeds': 13,
#          'boneless beef chuck roast': 3,
#          'hard-boiled egg': 6,
#          'pork tenderloin': 24,
#          'bulk italian sausag': 21,
#          'beef bouillon granules': 3,
#          'prebaked pizza crusts': 13,
#          'buttermilk': 32,
#          'flaked coconut': 5,
#          'lower sodium chicken broth': 20,
#          'carnaroli rice': 13,
#          'fresh oregano leaves': 24,
#          'cavatappi': 9,
#          'cooking oil': 24,
#          'cayenne': 8,
#          'ground cloves': 30,
#          'corn syrup': 4,
#          'small pasta': 7,
#          'ground fennel': 7,
#          'low-fat buttermilk': 9,
#          'ice': 7,
#          'chicken bouillon granules': 6,
#          'poultry seasoning': 10,
#          'roast': 3,
#          'fusilli': 43,
#          'Italian herbs': 7,
#          'diced yellow onion': 1,
#          'manicotti pasta': 4,
#          'parsley flakes': 17,
#          'vinaigrette': 7,
#          'bread ciabatta': 16,
#          'kidney beans': 12,
#          'creole seasoning': 4,
#          'prepared pasta sauce': 5,
#          'small curd cottage cheese': 14,
#          'white sandwich bread': 9,
#          'mini chocolate chips': 5,
#          'lean beef': 2,
#          'breadstick': 13,
#          'pickled okra': 2,
#          'fronds': 15,
#          'thick-cut bacon': 11,
#          'boiling potatoes': 13,
#          'ditalini': 11,
#          'cranberry beans': 4,
#          'center cut bacon': 7,
#          'roasting chickens': 8,
#          'fleur de sel': 6,
#          'Margherita Pepperoni': 1,
#          'soft-shell clams': 1,
#          'liquid': 5,
#          'fresh chevre': 4,
#          'pork sausages': 14,
#          'dried minced onion': 5,
#          'msg': 2,
#          'pork stew meat': 1,
#          'beef stew meat': 3,
#          'ziti': 26,
#          'Balsamico Bianco': 2,
#          'ground mustard': 1,
#          ...})

# %% [markdown]
# ## Ingredients

# %% [markdown]
# We will look at the most common ingredients overally and at the most common ingredients for each cuisine:

# %%
ingredients_counts = {}

for recipe_ingr in df['ingredients']:
    for ingr in recipe_ingr:
        count = ingredients_counts.get(ingr.lower(), 0)
        ingredients_counts[ingr.lower()] = count + 2

# %%
ingredients_counts
# Out:
# {'romaine lettuce': 540,
#  'black olives': 458,
#  'grape tomatoes': 456,
#  'garlic': 14760,
#  'pepper': 8876,
#  'purple onion': 3792,
#  'seasoning': 274,
#  'garbanzo beans': 296,
#  'feta cheese crumbles': 716,
#  'plain flour': 308,
#  'ground pepper': 770,
#  'salt': 36098,
#  'tomatoes': 6116,
#  'ground black pepper': 9570,
#  'thyme': 722,
#  'eggs': 6776,
#  'green tomatoes': 216,
#  'yellow corn meal': 682,
#  'milk': 4526,
#  'vegetable oil': 8770,
#  'mayonaise': 1562,
#  'cooking oil': 966,
#  'green chilies': 1536,
#  'grilled chicken breasts': 10,
#  'garlic powder': 2884,
#  'yellow onion': 2368,
#  'soy sauce': 6592,
#  'butter': 9696,
#  'chicken livers': 130,
#  'water': 14914,
#  'wheat': 52,
#  'black pepper': 5254,
#  'shallots': 2954,
#  'cornflour': 206,
#  'cayenne pepper': 3046,
#  'onions': 15944,
#  'garlic paste': 564,
#  'lemon juice': 2790,
#  'chili powder': 4072,
#  'passata': 48,
#  'oil': 3940,
#  'ground cumin': 5494,
#  'boneless chicken skinless thigh': 686,
#  'garam masala': 1850,
#  'double cream': 80,
#  'natural yogurt': 36,
#  'bay leaf': 1678,
#  'sugar': 12868,
#  'fresh ginger root': 676,
#  'ground cinnamon': 2462,
#  'vanilla extract': 2596,
#  'ground ginger': 1356,
#  'powdered sugar': 1002,
#  'baking powder': 3476,
#  'olive oil': 15944,
#  'medium shrimp': 922,
#  'chopped cilantro': 1592,
#  'jalapeno chilies': 3460,
#  'flat leaf parsley': 2188,
#  'skirt steak': 146,
#  'white vinegar': 1108,
#  'sea salt': 1880,
#  'chorizo sausage': 206,
#  'pistachio nuts': 44,
#  'white almond bark': 2,
#  'flour': 2696,
#  'almond extract': 346,
#  'dried cranberries': 102,
#  'fresh pineapple': 112,
#  'pork': 600,
#  'poblano peppers': 238,
#  'corn tortillas': 1930,
#  'cheddar cheese': 848,
#  'iceberg lettuce': 328,
#  'lime': 2878,
#  'chopped cilantro fresh': 3396,
#  'chopped tomatoes': 596,
#  'fresh basil': 2274,
#  'extra-virgin olive oil': 5494,
#  'kosher salt': 6226,
#  'pimentos': 268,
#  'sweet pepper': 124,
#  'dried oregano': 3414,
#  'sharp cheddar cheese': 308,
#  'swiss cheese': 110,
#  'provolone cheese': 330,
#  'canola oil': 2446,
#  'mushrooms': 1156,
#  'sausages': 370,
#  'low sodium soy sauce': 850,
#  'fresh ginger': 3006,
#  'dry mustard': 304,
#  'green beans': 682,
#  'white pepper': 878,
#  'sesame oil': 3546,
#  'scallions': 3782,
#  'shaoxing wine': 528,
#  'ground turkey': 336,
#  'crushed red pepper flakes': 1010,
#  'corn starch': 3514,
#  'italian parsley leaves': 250,
#  'walnuts': 228,
#  'hot red pepper flakes': 342,
#  'fresh lemon juice': 3358,
#  'trout fillet': 26,
#  'garlic cloves': 12474,
#  'chipotle chile': 300,
#  'fine sea salt': 570,
#  'fresh cilantro': 1682,
#  'ground coriander': 1536,
#  'plum tomatoes': 1716,
#  'avocado': 2458,
#  'lime juice': 2144,
#  'flank steak': 516,
#  'fresh parmesan cheese': 572,
#  'all-purpose flour': 9264,
#  'fat free less sodium chicken broth': 946,
#  'chopped fresh chives': 454,
#  'gruyere cheese': 198,
#  'bacon slices': 424,
#  'gnocchi': 82,
#  'fat free milk': 268,
#  'cooking spray': 2980,
#  'tumeric': 1476,
#  'vegetable stock': 384,
#  'naan': 74,
#  'red lentils': 220,
#  'red chili peppers': 1288,
#  'spinach': 732,
#  'sweet potatoes': 910,
#  'greek yogurt': 466,
#  'lemon curd': 10,
#  'confectioners sugar': 790,
#  'raspberries': 162,
#  'italian seasoning': 790,
#  'broiler-fryer chicken': 16,
#  'zesty italian dressing': 34,
#  'hot chili': 38,
#  'asian fish sauce': 316,
#  'red bell pepper': 3878,
#  'chicken broth': 3108,
#  'yellow squash': 232,
#  'garlic chili sauce': 260,
#  'sliced green onions': 944,
#  'broccolini': 44,
#  'fresh lime juice': 2736,
#  'cooked rice': 774,
#  'chicken breasts': 1586,
#  'pork loin': 142,
#  'roasted peanuts': 312,
#  'hoisin sauce': 858,
#  'creamy peanut butter': 222,
#  'chopped fresh mint': 634,
#  'thai basil': 356,
#  'rice': 1018,
#  'rice noodles': 526,
#  'beansprouts': 908,
#  'roma tomatoes': 454,
#  'low-fat mayonnaise': 40,
#  'baking potatoes': 414,
#  'spicy brown mustard': 44,
#  'sesame seeds': 1352,
#  'red pepper': 918,
#  'yellow peppers': 102,
#  'extra firm tofu': 274,
#  'broccoli': 440,
#  'orange bell pepper': 186,
#  'arrowroot powder': 28,
#  'red curry paste': 244,
#  'marinara sauce': 458,
#  'linguine': 496,
#  'capers': 1082,
#  'olives': 310,
#  'lemon zest': 498,
#  'lo mein noodles': 56,
#  'light soy sauce': 694,
#  'dried black mushrooms': 18,
#  'chives': 412,
#  'oyster sauce': 910,
#  'dark soy sauce': 624,
#  'peanuts': 812,
#  'cabbage': 832,
#  'herbs': 174,
#  'fresh tomatoes': 296,
#  'paprika': 2574,
#  'mango': 536,
#  'stock': 180,
#  'chile pepper': 680,
#  'sliced mushrooms': 488,
#  'sherry': 158,
#  'grated parmesan cheese': 3772,
#  'heavy cream': 2292,
#  'spaghetti': 684,
#  'cooked chicken': 592,
#  'green bell pepper': 2360,
#  'egg roll wrappers': 114,
#  'sweet and sour sauce': 26,
#  'molasses': 212,
#  'shredded cabbage': 222,
#  'ground pork': 946,
#  'carrots': 5628,
#  'flour tortillas': 1730,
#  'cheese': 894,
#  'breakfast sausages': 60,
#  'large eggs': 5896,
#  'boiling water': 700,
#  'hot sauce': 1348,
#  'potatoes': 2036,
#  'bacon': 1240,
#  'fresh parsley': 3208,
#  'andouille sausage': 534,
#  'cajun seasoning': 752,
#  'peanut oil': 1220,
#  'celery': 1674,
#  'ground red pepper': 1076,
#  'shrimp': 1824,
#  'onion powder': 1056,
#  'firm tofu': 414,
#  'turnips': 226,
#  'palm sugar': 244,
#  'sliced chicken': 10,
#  'fish sauce': 2494,
#  'lime wedges': 964,
#  'green papaya': 52,
#  'chile powder': 240,
#  'tamarind paste': 168,
#  'chinese chives': 74,
#  'crushed garlic': 214,
#  'green onions': 6156,
#  'white sugar': 2186,
#  'dried basil': 1170,
#  'diced tomatoes': 3248,
#  'johnsonville andouille dinner sausage': 2,
#  'parsley': 690,
#  'jambalaya rice mix': 4,
#  'worcestershire sauce': 1376,
#  'hot pepper sauce': 612,
#  'creole seasoning': 552,
#  'bread slices': 100,
#  'great northern beans': 100,
#  'sage leaves': 228,
#  'chinese five-spice powder': 506,
#  'chicken thighs': 672,
#  'star anise': 518,
#  'cream cheese': 1124,
#  'shredded cheddar cheese': 1538,
#  'black-eyed peas': 392,
#  'tortilla chips': 604,
#  'collard greens': 334,
#  'ham hock': 88,
#  'chicken stock': 2078,
#  'apple cider': 84,
#  'freshly ground pepper': 1898,
#  'bay leaves': 2072,
#  'rib': 118,
#  'light brown sugar': 844,
#  'large garlic cloves': 1746,
#  'oscar mayer deli fresh smoked ham': 6,
#  'hoagie rolls': 32,
#  'salami': 108,
#  'giardiniera': 22,
#  'mozzarella cheese': 934,
#  'pepperoni': 104,
#  'ice cubes': 260,
#  'club soda': 90,
#  'white rum': 30,
#  'turbinado': 100,
#  'enchilada sauce': 590,
#  'picante sauce': 112,
#  'green pepper': 746,
#  'canned black beans': 158,
#  'shredded lettuce': 350,
#  'sour cream': 3078,
#  'salmon fillets': 318,
#  'cumin seed': 1870,
#  'curry powder': 1388,
#  'serrano chile': 598,
#  'sauce': 916,
#  'chicken breast halves': 304,
#  'lettuce leaves': 378,
#  'chopped onion': 2502,
#  'mandarin oranges': 62,
#  'orange liqueur': 122,
#  'yellow cake mix': 32,
#  'frosting': 38,
#  'fennel bulb': 410,
#  'lemon olive oil': 2,
#  'grapefruit juice': 30,
#  'white cornmeal': 170,
#  'bacon drippings': 132,
#  'buttermilk': 1726,
#  'crab boil': 34,
#  'old bay seasoning': 196,
#  'crawfish': 236,
#  'sirloin': 48,
#  'mirin': 1006,
#  'corn oil': 242,
#  'glass noodles': 78,
#  'sake': 690,
#  'shiitake': 662,
#  'napa cabbage': 452,
#  'whipping cream': 1238,
#  'extra sharp cheddar cheese': 102,
#  'quickcooking grits': 172,
#  'monterey jack': 470,
#  'crushed red pepper': 1650,
#  'mussels': 350,
#  'basil': 564,
#  'dry white wine': 2436,
#  'finely chopped onion': 914,
#  'baking soda': 1884,
#  'honey': 2598,
#  'unsalted butter': 5564,
#  'lemon': 2436,
#  'pesto': 236,
#  'white wine': 734,
#  'bread crumbs': 612,
#  'curry': 136,
#  'low sodium beef broth': 52,
#  'pickapeppa sauce': 8,
#  'cold water': 1012,
#  'allspice': 258,
#  'fresh thyme': 690,
#  'ground beef': 1756,
#  'melted butter': 552,
#  'matcha green tea powder': 22,
#  'chopped walnuts': 256,
#  'coarse salt': 1156,
#  'fenugreek': 72,
#  'urad dal': 136,
#  'white rice': 496,
#  'pizza crust': 88,
#  'part-skim mozzarella cheese': 454,
#  'yukon gold potatoes': 436,
#  'low-fat sour cream': 124,
#  'leeks': 870,
#  '1% low-fat milk': 386,
#  'lemongrass': 728,
#  'unsweetened coconut milk': 382,
#  'peanut sauce': 40,
#  'spareribs': 28,
#  'tamari soy sauce': 180,
#  'golden brown sugar': 166,
#  'dry sherry': 512,
#  'chicken legs': 234,
#  'ghee': 614,
#  'tomato paste': 2316,
#  'ground turmeric': 1898,
#  'cracked black pepper': 816,
#  'minced beef': 60,
#  'dried thyme': 1746,
#  'ginger': 3510,
#  'chillies': 242,
#  'crushed tomatoes': 906,
#  'fresh rosemary': 884,
#  'boneless pork loin': 124,
#  'pappardelle': 22,
#  'coconut milk': 1708,
#  'eggplant': 1002,
#  'jasmine rice': 304,
#  'gochujang base': 284,
#  'top round steak': 54,
#  'rice vinegar': 2408,
#  'taiwanese bok choy': 2,
#  'vanilla': 622,
#  'large egg yolks': 1150,
#  'orange juice concentrate': 38,
#  'pumpkin pură©e': 38,
#  'marshmallow creme': 30,
#  'toasted pecans': 50,
#  'maple syrup': 220,
#  'gingersnap': 8,
#  'ground nutmeg': 1210,
#  'brown sugar': 3006,
#  'serrano ham': 56,
#  'manchego cheese': 120,
#  'dijon mustard': 1026,
#  'sourdough': 20,
#  'membrillo': 2,
#  'burger buns': 10,
#  'panko breadcrumbs': 288,
#  'chickpea flour': 102,
#  'sriracha': 596,
#  'chickpeas': 804,
#  'ground flaxseed': 8,
#  'greens': 192,
#  'tahini': 124,
#  'ground cloves': 742,
#  'whole nutmegs': 30,
#  'ground cardamom': 474,
#  'italian bread': 236,
#  'balsamic vinegar': 1148,
#  'sausage casings': 216,
#  'shredded mozzarella cheese': 950,
#  'roasted red peppers': 478,
#  'penne pasta': 356,
#  'saffron': 412,
#  'warm water': 1154,
#  'preserved lemon': 126,
#  'harissa': 84,
#  'couscous': 378,
#  'cayenne': 940,
#  'fat skimmed chicken broth': 156,
#  'pitted kalamata olives': 408,
#  'fat': 184,
#  'sweetened condensed milk': 542,
#  'ice': 222,
#  'espresso': 32,
#  'fresh asparagus': 86,
#  'pecans': 288,
#  'crumbled blue cheese': 74,
#  'chuck': 134,
#  'hamburger buns': 108,
#  'okra pods': 54,
#  'watercress': 208,
#  'self rising flour': 386,
#  'softened butter': 98,
#  'food colouring': 64,
#  'madeira': 66,
#  'foie gras': 24,
#  'demi-glace': 10,
#  'sherry vinegar': 320,
#  'white bread': 260,
#  'fuyu persimmons': 6,
#  'egg bread': 8,
#  'fenugreek leaves': 118,
#  'black mustard seeds': 224,
#  'amchur': 174,
#  'coriander': 916,
#  'fingerling potatoes': 40,
#  'ramps': 22,
#  'black peppercorns': 906,
#  'cinnamon sticks': 1292,
#  'cardamom pods': 308,
#  'coriander seeds': 790,
#  'asiago': 170,
#  'whole wheat pasta': 36,
#  'sweet onion': 672,
#  'chestnuts': 62,
#  'granulated sugar': 1698,
#  'whole milk ricotta cheese': 106,
#  'coffee ice cream': 14,
#  'mascarpone': 298,
#  'rum': 154,
#  'semisweet chocolate': 328,
#  'chestnut flour': 2,
#  'baby spinach leaves': 206,
#  'chopped garlic': 690,
#  'large shrimp': 828,
#  'barley': 16,
#  'cooked ham': 148,
#  'starchy potatoes': 10,
#  'grated nutmeg': 468,
#  'sirloin tip roast': 10,
#  'steak': 128,
#  'vegetable shortening': 276,
#  'finely chopped fresh parsley': 168,
#  'vinegar': 632,
#  'caul fat': 6,
#  'whole milk': 1528,
#  'heavy whipping cream': 432,
#  'kahlăşa': 42,
#  'instant espresso powder': 122,
#  'epazote': 86,
#  'radishes': 564,
#  'oregano': 880,
#  'white onion': 1368,
#  'hominy': 154,
#  'tomatillos': 644,
#  'pepitas': 42,
#  'catfish fillets': 218,
#  'basmati rice': 652,
#  'cauliflower': 442,
#  'cumin': 1906,
#  'blood orange': 24,
#  'low salt chicken broth': 770,
#  'white wine vinegar': 704,
#  'tomato sauce': 1730,
#  'shredded carrots': 312,
#  'english muffins, split and toasted': 6,
#  'vegetable oil cooking spray': 520,
#  'chopped green bell pepper': 536,
#  'prawns': 184,
#  'rice flour': 260,
#  'seasoning salt': 262,
#  'lasagna noodles': 418,
#  'ranch dressing': 146,
#  'evaporated milk': 416,
#  'minced garlic': 3166,
#  'red wine vinegar': 1504,
#  'boneless chop pork': 70,
#  'chile paste': 90,
#  'lower sodium soy sauce': 114,
#  'dark sesame oil': 402,
#  'raisins': 920,
#  'pearl barley': 62,
#  'slivered almonds': 334,
#  'chocolate bars': 16,
#  'marshmallows': 14,
#  'cinnamon graham crackers': 2,
#  'chopped celery': 852,
#  'mustard powder': 104,
#  'cod': 72,
#  'minced onion': 378,
#  'dry bread crumbs': 574,
#  'golden raisins': 480,
#  'margarine': 440,
#  'mace': 162,
#  'brewed tea': 6,
#  'candied orange peel': 54,
#  'grated lemon zest': 684,
#  'dried currants': 190,
#  'rum extract': 6,
#  'dark brown sugar': 638,
#  'noodles': 450,
#  'baby bok choy': 172,
#  'black bean sauce': 62,
#  'red potato': 410,
#  'chinese rice wine': 262,
#  'black beans': 1792,
#  'quinoa': 232,
#  'frozen corn': 350,
#  'vegetable broth': 818,
#  'yellow bell pepper': 582,
#  'orange': 710,
#  'duck': 98,
#  'dried mint flakes': 62,
#  'penne rigate': 36,
#  'feta cheese': 536,
#  'ras el hanout': 88,
#  'ground lamb': 272,
#  'large egg whites': 970,
#  '2% reduced-fat milk': 142,
#  'napa cabbage leaves': 34,
#  'chicken leg quarters': 50,
#  'cucumber': 1536,
#  'long-grain rice': 706,
#  'crusty bread': 84,
#  'baby potatoes': 38,
#  'smoked streaky bacon': 8,
#  'piloncillo': 44,
#  'ground allspice': 728,
#  'hibiscus': 4,
#  'fresh oregano': 788,
#  'chocolate morsels': 42,
#  'cream sweeten whip': 78,
#  'instant espresso granules': 12,
#  'chocolate covered coffee beans': 6,
#  'unflavored gelatin': 216,
#  'pound cake': 30,
#  'pinenuts': 696,
#  'zucchini': 1784,
#  'baby carrots': 144,
#  'fresh basil leaves': 1004,
#  'asparagus spears': 124,
#  'frozen peas': 766,
#  'arborio rice': 584,
#  'yellow crookneck squash': 18,
#  'chipotles in adobo': 386,
#  'instant white rice': 20,
#  'cilantro leaves': 2320,
#  'red beans': 136,
#  'skinless chicken thighs': 18,
#  'lime zest': 274,
#  'condensed cream of mushroom soup': 110,
#  'condensed cream of chicken soup': 124,
#  'lean ground beef': 776,
#  'mexican cheese blend': 348,
#  'chunky salsa': 140,
#  'taco seasoning mix': 362,
#  'chorizo spanish': 2,
#  'pineapple juice': 164,
#  'dark rum': 232,
#  'daikon': 300,
#  'pork ribs': 60,
#  'goji berries': 14,
#  'oysters': 120,
#  'salsa': 1926,
#  'demerara sugar': 22,
#  'egg whites': 906,
#  'fruit': 100,
#  'frozen pastry puff sheets': 212,
#  'mixed spice': 66,
#  'parsnips': 136,
#  'chili oil': 218,
#  'brown mustard seeds': 114,
#  'unsalted cashews': 54,
#  'thai green curry paste': 100,
#  'kecap manis': 34,
#  'frozen broad beans': 6,
#  'basil leaves': 534,
#  'chili flakes': 316,
#  'chicken tenderloin': 42,
#  'creole style seasoning': 18,
#  'condensed cheddar cheese soup': 12,
#  'refried beans': 500,
#  'grated jack cheese': 120,
#  'egg yolks': 1084,
#  'asparagus': 460,
#  'fresh leav spinach': 114,
#  'cheese tortellini': 110,
#  'cherry tomatoes': 872,
#  'navy beans': 44,
#  'nonfat milk': 36,
#  'granny smith apples': 238,
#  'lard': 314,
#  'pecorino romano cheese': 314,
#  'fresh fava bean': 30,
#  'italian sausage': 274,
#  'pasta sheets': 18,
#  'spinach leaves': 144,
#  'low-fat natural yogurt': 8,
#  'flora cuisine': 22,
#  'curry paste': 212,
#  'bone-in chicken breasts': 38,
#  'white hominy': 138,
#  'dried chile peppers': 10,
#  'frozen whipped topping': 28,
#  'chocolate instant pudding': 20,
#  'instant butterscotch pudding mix': 2,
#  'graham cracker crumbs': 74,
#  'fennel seeds': 704,
#  'kalamata': 392,
#  'kielbasa': 56,
#  'celery ribs': 1134,
#  'ham': 444,
#  'moong dal': 46,
#  'capsicum': 100,
#  'green mango': 20,
#  'toasted sesame oil': 710,
#  'tofu': 272,
#  'short-grain rice': 124,
#  'dried shiitake mushrooms': 248,
#  'gari': 100,
#  'turkish bay leaves': 36,
#  'dried chickpeas': 44,
#  'semolina': 120,
#  'vine ripened tomatoes': 68,
#  'bittersweet chocolate': 280,
#  'fat free yogurt': 140,
#  'skim milk': 162,
#  'angel food cake': 10,
#  'unsweetened cocoa powder': 532,
#  'instant espresso': 26,
#  'organic chicken': 18,
#  'anise': 124,
#  'zinfandel': 20,
#  'orange blossom honey': 22,
#  'calimyrna figs': 30,
#  'clove': 1200,
#  'plain whole-milk yogurt': 98,
#  'reduced sodium soy sauce': 314,
#  'beef stock': 320,
#  'chuck roast': 132,
#  'corn flakes cereal': 14,
#  'coleslaw': 44,
#  'garlic salt': 480,
#  'chili paste': 244,
#  'red pepper flakes': 1338,
#  'kiwi': 52,
#  'asian pear': 88,
#  'chees fresco queso': 68,
#  'swiss chard': 206,
#  'veal cutlets': 42,
#  'pasta': 642,
#  'wakame': 38,
#  'extra-lean ground beef': 22,
#  'scallion greens': 122,
#  'wonton wrappers': 316,
#  'peeled fresh ginger': 1164,
#  'nonstick spray': 100,
#  'chopped fresh thyme': 750,
#  'chicken bones': 22,
#  'green bell pepper, slice': 98,
#  'anchovy fillets': 378,
#  'crusty rolls': 12,
#  'coconut oil': 442,
#  'almond flour': 80,
#  'coconut aminos': 34,
#  'green peas': 424,
#  'clams': 188,
#  'boneless skinless chicken breast halves': 1236,
#  'seasoned rice wine vinegar': 120,
#  'snow peas': 366,
#  'hard-boiled egg': 208,
#  'artichoke hearts': 270,
#  'stuffing': 34,
#  'coriander powder': 492,
#  'maida flour': 34,
#  'pita bread rounds': 42,
#  'grated gruyă¨re cheese': 122,
#  'udon': 96,
#  'red miso': 58,
#  'silken tofu': 88,
#  'button mushrooms': 326,
#  'whole peeled tomatoes': 254,
#  'shredded monterey jack cheese': 650,
#  'pickled jalapenos': 54,
#  'broccoli rabe': 96,
#  'parmigiano reggiano cheese': 706,
#  'fontina': 58,
#  'thai chile': 446,
#  'peppercorns': 288,
#  'refrigerated piecrusts': 142,
#  'cream of chicken soup': 166,
#  'frozen peas and carrots': 40,
#  'low sodium chicken broth': 678,
#  'pasta sauce': 532,
#  'olive oil flavored cooking spray': 94,
#  'frozen chopped spinach': 412,
#  'part-skim ricotta cheese': 250,
#  'manicotti shells': 40,
#  'fettucine': 318,
#  'parmesan cheese': 1182,
#  'chicken bouillon': 154,
#  'chili paste with garlic': 20,
#  'fresh veget': 8,
#  'taco sauce': 126,
#  'guacamole': 370,
#  'salsa verde': 270,
#  'condiments': 20,
#  'pork shoulder roast': 56,
#  'tortillas': 444,
#  'rose petals': 10,
#  'almonds': 388,
#  'pistachios': 128,
#  'chicken wings': 266,
#  'drumstick': 14,
#  'green chile': 604,
#  'peeled tomatoes': 146,
#  'chicken': 1964,
#  'chiles': 642,
#  'adobo sauce': 188,
#  'ancho powder': 156,
#  'chipotle chile powder': 84,
#  'old el paso flour tortillas': 10,
#  'cranberry sauce': 10,
#  'beer': 404,
#  'chili sauce': 294,
#  'beef rib short': 142,
#  'miso paste': 146,
#  'seaweed': 114,
#  'dashi': 256,
#  'fresh dill': 486,
#  'yoghurt': 494,
#  'myzithra': 4,
#  'phyllo': 38,
#  'kefalotyri': 18,
#  'okra': 536,
#  'cracker crumbs': 28,
#  'philadelphia cream cheese': 42,
#  'crab meat': 66,
#  'savoy cabbage': 110,
#  'boneless chicken thighs': 106,
#  'potato starch': 118,
#  'cream of tartar': 318,
#  'semi-sweet chocolate morsels': 154,
#  'cake flour': 358,
#  'ricotta cheese': 704,
#  'serrano': 64,
#  'steel-cut oats': 14,
#  'hazelnuts': 200,
#  'hazelnut oil': 18,
#  'sweet cherries': 42,
#  'fire roasted diced tomatoes': 32,
#  'red kidnei beans, rins and drain': 36,
#  'wasabi paste': 78,
#  'black sesame seeds': 92,
#  'japanese soy sauce': 58,
#  'fresh salmon': 10,
#  'dried porcini mushrooms': 200,
#  'dry red wine': 618,
#  'hot water': 712,
#  'fat free less sodium beef broth': 38,
#  'cremini mushrooms': 276,
#  'creole mustard': 130,
#  'prepared horseradish': 144,
#  'celery salt': 104,
#  'shrimp and crab boil seasoning': 18,
#  'turnip greens': 56,
#  'butternut squash': 348,
#  'apples': 330,
#  'country ham': 96,
#  'frozen edamame beans': 36,
#  'whole kernel corn, drain': 212,
#  'strong white bread flour': 32,
#  'salted butter': 154,
#  'sunflower oil': 194,
#  'kalonji': 12,
#  'instant yeast': 148,
#  'fresh coriander': 570,
#  'cooked white rice': 290,
#  'mixed mushrooms': 16,
#  'wood ear mushrooms': 58,
#  'vegetables': 394,
#  'taco seasoning': 542,
#  'bell pepper': 774,
#  'boneless skinless chicken breasts': 2222,
#  'shredded cheese': 314,
#  'eau de vie': 8,
#  'leaves': 186,
#  'cane sugar': 40,
#  'baking apples': 6,
#  'salt and ground black pepper': 430,
#  'sliced black olives': 322,
#  'chopped green chilies': 116,
#  'rosemary leaves': 42,
#  'lean steak': 8,
#  'guinness lager': 2,
#  'dried rosemary': 346,
#  'water chestnuts, drained and chopped': 20,
#  'chinese cabbage': 118,
#  'dipping sauces': 118,
#  'lean ground pork': 86,
#  'pico de gallo': 158,
#  'cheese slices': 40,
#  'chorizo': 136,
#  'french bread': 384,
#  'dried dillweed': 68,
#  'red wine': 458,
#  'lamb': 124,
#  'plain yogurt': 728,
#  'kale': 314,
#  'mexican beer': 60,
#  'boneless beef short ribs': 12,
#  'guajillo': 26,
#  'saffron threads': 554,
#  'fresh spinach': 460,
#  'banana squash': 6,
#  'cannellini beans': 406,
#  'shortening': 458,
#  'franks hot sauce': 2,
#  'pears': 194,
#  'light pancake syrup': 20,
#  'puff pastry': 102,
#  'apple cider vinegar': 536,
#  'mushroom powder': 4,
#  'bone in chicken thighs': 74,
#  'fresh bay leaves': 42,
#  'cilantro': 2284,
#  'skinless chicken breasts': 122,
#  'light sour cream': 110,
#  'fava beans': 54,
#  'fresh tarragon': 284,
#  'kidney beans': 318,
#  'orzo pasta': 66,
#  'dri leav thyme': 70,
#  'wasabi': 64,
#  'jumbo shrimp': 126,
#  'sticky rice': 64,
#  'white sesame seeds': 152,
#  'chopped almonds': 94,
#  'baby arugula': 94,
#  'tequila': 266,
#  'margarita mix': 10,
#  'crust': 56,
#  'grits': 368,
#  'pecan halves': 204,
#  'corn syrup': 126,
#  'superfine sugar': 146,
#  'blackberries': 182,
#  'whiskey': 60,
#  'luke warm water': 14,
#  'active dry yeast': 754,
#  'fresh mint': 832,
#  'jamaican jerk season': 44,
#  'pineapple preserves': 6,
#  'chicken drumsticks': 188,
#  'pitas': 94,
#  'goat cheese': 338,
#  'gingerroot': 238,
#  'rib eye steaks': 92,
#  'hot bean paste': 18,
#  'medjool date': 46,
#  'diced bell pepper': 18,
#  'cream': 516,
#  'smoked paprika': 690,
#  'reduced fat milk': 152,
#  'smoked trout': 8,
#  'garlic puree': 32,
#  'green cardamom pods': 160,
#  'tomato pură©e': 434,
#  'pickled jalapeno peppers': 14,
#  'romaine lettuce leaves': 82,
#  'crema mexicana': 44,
#  'chile sauce': 78,
#  'queso fresco': 282,
#  'boston lettuce': 54,
#  'persian cucumber': 48,
#  'peanut butter': 244,
#  'rice paper': 138,
#  'korean chile flakes': 44,
#  'red chile powder': 38,
#  'boneless chicken breast': 292,
#  'cashew nuts': 436,
#  'kashmiri chile': 4,
#  'kasuri methi': 102,
#  'mustard oil': 64,
#  'ginger paste': 238,
#  'cinnamon': 1392,
#  'tomato ketchup': 138,
#  'pecan pie': 2,
#  'tostada shells': 48,
#  'grouper': 32,
#  'corn kernels': 560,
#  'ricotta salata': 52,
#  'pecorino cheese': 110,
#  'grana padano': 16,
#  'kaffir lime leaves': 266,
#  'corn': 658,
#  'soba noodles': 136,
#  'galangal': 170,
#  'green curry paste': 92,
#  'bamboo shoots': 274,
#  'chopped nuts': 28,
#  'bourbon whiskey': 398,
#  'ketchup': 864,
#  'rhubarb': 46,
#  'liquid': 120,
#  'store bought low sodium chicken stock': 62,
#  'safflower oil': 72,
#  'jeera': 54,
#  'cardamom': 212,
#  'crema': 72,
#  'salmon steaks': 26,
#  'jam': 54,
#  'karashi': 4,
#  'spring onions': 814,
#  'free range egg': 46,
#  'jicama': 176,
#  'water chestnuts': 390,
#  'diced celery': 172,
#  'shredded sharp cheddar cheese': 334,
#  'dinner rolls': 20,
#  'cactus pad': 6,
#  'fenugreek seeds': 146,
#  'cauliflower flowerets': 6,
#  'boiling potatoes': 198,
#  'baby spinach': 514,
#  'tuna steaks': 80,
#  'spices': 342,
#  'octopuses': 22,
#  'vidalia onion': 230,
#  'smoked gouda': 52,
#  'small red potato': 158,
#  'tuna': 88,
#  'fat-free refried beans': 26,
#  'low-fat milk': 88,
#  'fresh lime': 58,
#  'ground white pepper': 696,
#  'bertolliâ® classico olive oil': 32,
#  'bacon, crisp-cooked and crumbled': 6,
#  'bertolli vineyard premium collect marinara with burgundi wine sauc': 10,
#  'bread crumb fresh': 340,
#  'margarita salt': 6,
#  '(    oz.) tomato sauce': 22,
#  'ground veal': 86,
#  'italian seasoning mix': 8,
#  'beef': 546,
#  'solid pack pumpkin': 28,
#  'fresh thyme leaves': 380,
#  'whole grain thin spaghetti': 2,
#  'grapeseed oil': 158,
#  'organic sugar': 14,
#  'dried cherry': 42,
#  'straw mushrooms': 62,
#  'vidalia': 8,
#  'haricots verts': 108,
#  'wax beans': 12,
#  'prosciutto': 568,
#  'romano cheese': 212,
#  'cooked shrimp': 184,
#  'crabmeat': 158,
#  'strawberries': 438,
#  'green peppercorns': 36,
#  'pork loin chops': 106,
#  'chipotle peppers': 134,
#  'blueberri preserv': 2,
#  'filet': 68,
#  'thyme leaves': 82,
#  'coffee beans': 34,
#  'vegan margarine': 12,
#  'pork shoulder': 270,
#  'parsley leaves': 120,
#  'fresh raspberries': 184,
#  'frozen whole kernel corn': 168,
#  'wish bone guacamol ranch dress': 2,
#  'torn romain lettuc leav': 6,
#  'russet potatoes': 532,
#  'mexican chorizo': 66,
#  'colby cheese': 48,
#  'half & half': 674,
#  'dry vermouth': 78,
#  'canned low sodium chicken broth': 192,
#  'roasted salted cashews': 6,
#  'fresh lemon': 54,
#  'toasted sesame seeds': 588,
#  'paneer cheese': 20,
#  'lemon grass': 200,
#  'thai fish sauce': 216,
#  ...}

# %%
n_ingredients = len(ingredients_counts)
n_ingredients
# Out:
# 6703

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# Many ingredients have more than one name, like for example olive oil, soy sauce, garlic cloves, or some words use different words for describing the same ingredient like tometoes, sliced tomatoes, diced tomatoes, chopped tomatoes, plum tomatoes...

# %% [markdown]
# ## Lower-casing

# %%
df['ingredients'] = df['ingredients'].apply(lambda i: list(map(lambda x: x.lower(), i)))

# %% [markdown]
# ## Punctation removal

# %%
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

# %%
df['ingredients'].apply(lambda i: list(map(lambda x: remove_punctuations(x), i)))
# Out:
# 0        [romaine lettuce, black olives, grape tomatoes...
# 1        [plain flour, ground pepper, salt, tomatoes, g...
# 2        [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3                      [water, vegetable oil, wheat, salt]
# 4        [black pepper, shallots, cornflour, cayenne pe...
# 5        [plain flour, sugar, butter, eggs, fresh ginge...
# 6        [olive oil, salt, medium shrimp, pepper, garli...
# 7        [sugar, pistachio nuts, white almond bark, flo...
# 8        [olive oil, purple onion, fresh pineapple, por...
# 9        [chopped tomatoes, fresh basil, garlic, extrav...
# 10       [pimentos, sweet pepper, dried oregano, olive ...
# 11       [low sodium soy sauce, fresh ginger, dry musta...
# 12       [italian parsley leaves, walnuts, hot red pepp...
# 13       [ground cinnamon, fresh cilantro, chili powder...
# 14       [fresh parmesan cheese, butter, allpurpose flo...
# 15       [tumeric, vegetable stock, tomatoes, garam mas...
# 16       [greek yogurt, lemon curd, confectioners sugar...
# 17       [italian seasoning, broilerfryer chicken, mayo...
# 18        [sugar, hot chili, asian fish sauce, lime juice]
# 19       [soy sauce, vegetable oil, red bell pepper, ch...
# 20       [pork loin, roasted peanuts, chopped cilantro ...
# 21       [roma tomatoes, kosher salt, purple onion, jal...
# 22       [lowfat mayonnaise, pepper, salt, baking potat...
# 23       [sesame seeds, red pepper, yellow peppers, wat...
# 24       [marinara sauce, flat leaf parsley, olive oil,...
# 25       [sugar, lo mein noodles, salt, chicken broth, ...
# 26       [herbs, lemon juice, fresh tomatoes, paprika, ...
# 27       [ground black pepper, butter, sliced mushrooms...
# 28       [green bell pepper, egg roll wrappers, sweet a...
# 29       [flour tortillas, cheese, breakfast sausages, ...
#                                ...
# 39744    [extravirgin olive oil, oregano, potatoes, gar...
# 39745    [quinoa, extravirgin olive oil, fresh thyme le...
# 39746    [clove, bay leaves, ginger, chopped cilantro, ...
# 39747    [water, sugar, grated lemon zest, butter, pitt...
# 39748    [sea salt, pizza doughs, allpurpose flour, cor...
# 39749    [kosher salt, minced onion, tortilla chips, su...
# 39750    [ground black pepper, chicken breasts, salsa, ...
# 39751    [olive oil, cayenne pepper, chopped cilantro f...
# 39752    [self rising flour, milk, white sugar, butter,...
# 39753    [rosemary sprigs, lemon zest, garlic cloves, g...
# 39754    [jasmine rice, bay leaves, sticky rice, rotiss...
# 39755    [mint leaves, cilantro leaves, ghee, tomatoes,...
# 39756    [vegetable oil, cinnamon sticks, water, allpur...
# 39757    [red bell pepper, garlic cloves, extravirgin o...
# 39758    [milk, salt, ground cayenne pepper, ground lam...
# 39759    [red chili peppers, sea salt, onions, water, c...
# 39760    [butter, large eggs, cornmeal, baking powder, ...
# 39761    [honey, chicken breast halves, cilantro leaves...
# 39762    [curry powder, salt, chicken, water, vegetable...
# 39763    [fettuccine pasta, lowfat cream cheese, garlic...
# 39764    [chili powder, worcestershire sauce, celery, r...
# 39765    [coconut, unsweetened coconut milk, mint leave...
# 39766    [rutabaga, ham, thickcut bacon, potatoes, fres...
# 39767    [lowfat sour cream, grated parmesan cheese, sa...
# 39768    [shredded cheddar cheese, crushed cheese crack...
# 39769    [light brown sugar, granulated sugar, butter, ...
# 39770    [kraft zesty italian dressing, purple onion, b...
# 39771    [eggs, citrus fruit, raisins, sourdough starte...
# 39772    [boneless chicken skinless thigh, minced garli...
# 39773    [green chile, jalapeno chilies, onions, ground...
# Name: ingredients, Length: 39774, dtype: object

# %% [markdown]
# ## Market basket analysis

# %%
def itemSetSupport(item_set, transactions):
    count = 0
    for transaction in transactions:
        if item_set.issubset(transaction):
            count = count + 1
    return count

# %%
def subset_check(to_add, L, k):
    for subset in itertools.combinations(L, k - 1):
        if subset not in L:
            return False
    return True

# %%
def apriori_gen(L, k):
    result = []
    for a in L:
        for b in L:
            if a != b and len(a.intersection(b)) == k - 2: 
                to_add = a.union(b)
                if subset_check(to_add, L, k):
                    result.append(to_add)
    return result

# %%
def apriori(ingr_counts, transactions, treshold):
    ingr_over_treshold = {k: v for k, v in ingr_counts.items() if v >= treshold}
    Ck_list = itertools.product(ingr_over_treshold, ingr_over_treshold)
    
    Ck = set(map(lambda x: frozenset(x), Ck_list))
    Lk = list(filter(lambda x: len(x) > 1 and itemSetSupport(x, transactions) >= treshold, Ck))
    
    result = Lk.copy()
    k = 3
    
    while True:
        Ck = apriori_gen(Lk, k)
        Lk = list(filter(lambda x: itemSetSupport(x, transactions) >= treshold, Ck))
        if len(Lk) > 0:
            result.append(Lk)
            k = k + 1
        else:
            break
    return result

# %%
def rules(items, transactions, rel_treshold):
    result = []
    items_support =  itemSetSupport(items, transactions)
    for i in range(1, len(items)):
        for comb in itertools.combinations(items, i):
            comb_set = set(comb)
            support = items_support / itemSetSupport(comb_set, transactions)
            if support >= rel_treshold:
                result.append((comb_set, items - comb_set, support, items_support / len(transactions), items_support))
    return result

# %%
def cuisineRules(cuisine, apriori_treshold, rel_treshold):
    cuisine_recipes = df[df['cuisine'] == cuisine]
    cuisine_transactions = list(map(lambda x: set(x), cuisine_recipes['ingredients']))
    
    ingr_result = apriori(counters[cuisine], cuisine_transactions, apriori_treshold)
    
    for s in ingr_result:
        rule_result = rules(s, cuisine_transactions, rel_treshold)
        for i in range(0, len(rule_result)):
            if 'salt' not in rule_result[i][1]:
                print_rule(rule_result[i])

# %%
def print_rule(rule_tuple):
    print(rule_tuple[0], ' -> ', rule_tuple[1], '; Rel = ', '{:05.2f}'.format(rule_tuple[2] * 100), '; Sup = ', '{:05.2f}'.format(rule_tuple[3] * 100), '(', rule_tuple[4], ')')

# %%
for cuisine in cuisine_counts.keys():
    print(cuisine)
    cuisineRules(cuisine, math.sqrt(cuisine_counts[cuisine]), 0.7)
# Out:
# italian
# {'baking powder'}  ->  frozenset({'all-purpose flour'}) ; Rel =  82.80 ; Sup =  01.96 ( 154 )
# mexican
# {'onion powder'}  ->  frozenset({'garlic powder'}) ; Rel =  75.41 ; Sup =  02.14 ( 138 )
# southern_us
# {'onion powder'}  ->  frozenset({'garlic powder'}) ; Rel =  75.86 ; Sup =  02.04 ( 88 )
# indian
# {'green cardamom'}  ->  frozenset({'clove'}) ; Rel =  71.43 ; Sup =  01.83 ( 55 )
# {'bay leaf'}  ->  frozenset({'onions'}) ; Rel =  75.42 ; Sup =  02.96 ( 89 )
# chinese
# {'flank steak'}  ->  frozenset({'corn starch'}) ; Rel =  76.39 ; Sup =  02.06 ( 55 )
# {'napa cabbage'}  ->  frozenset({'soy sauce'}) ; Rel =  73.81 ; Sup =  02.32 ( 62 )
# {'chicken broth'}  ->  frozenset({'soy sauce'}) ; Rel =  70.91 ; Sup =  04.38 ( 117 )
# french
# cajun_creole
# {'celery ribs'}  ->  frozenset({'onions'}) ; Rel =  75.14 ; Sup =  08.41 ( 130 )
# {'bell pepper'}  ->  frozenset({'onions'}) ; Rel =  76.47 ; Sup =  03.36 ( 52 )
# {'onion powder'}  ->  frozenset({'garlic powder'}) ; Rel =  77.27 ; Sup =  04.40 ( 68 )
# thai
# {'galangal'}  ->  frozenset({'lemongrass'}) ; Rel =  77.78 ; Sup =  04.09 ( 63 )
# japanese
# greek
# spanish
# korean
# {'beef'}  ->  frozenset({'soy sauce'}) ; Rel =  72.09 ; Sup =  03.73 ( 31 )
# {'spinach'}  ->  frozenset({'carrots'}) ; Rel =  78.38 ; Sup =  03.49 ( 29 )
# {'shiitake'}  ->  frozenset({'carrots'}) ; Rel =  74.47 ; Sup =  04.22 ( 35 )
# {'honey'}  ->  frozenset({'sesame oil'}) ; Rel =  72.50 ; Sup =  06.99 ( 58 )
# {'rice wine'}  ->  frozenset({'soy sauce'}) ; Rel =  80.36 ; Sup =  05.42 ( 45 )
# {'red pepper flakes'}  ->  frozenset({'soy sauce'}) ; Rel =  79.25 ; Sup =  05.06 ( 42 )
# {'beef'}  ->  frozenset({'sesame oil'}) ; Rel =  72.09 ; Sup =  03.73 ( 31 )
# {'honey'}  ->  frozenset({'soy sauce'}) ; Rel =  73.75 ; Sup =  07.11 ( 59 )
# {'oil'}  ->  frozenset({'soy sauce'}) ; Rel =  75.00 ; Sup =  03.61 ( 30 )
# {'spinach'}  ->  frozenset({'soy sauce'}) ; Rel =  78.38 ; Sup =  03.49 ( 29 )
# {'spinach'}  ->  frozenset({'sesame oil'}) ; Rel =  81.08 ; Sup =  03.61 ( 30 )
# {'rice wine'}  ->  frozenset({'sesame oil'}) ; Rel =  80.36 ; Sup =  05.42 ( 45 )
# vietnamese
# {'clove'}  ->  frozenset({'star anise'}) ; Rel =  90.62 ; Sup =  03.52 ( 29 )
# moroccan
# {'fresh cilantro'}  ->  frozenset({'olive oil'}) ; Rel =  75.00 ; Sup =  04.38 ( 36 )
# {'saffron'}  ->  frozenset({'onions'}) ; Rel =  73.21 ; Sup =  04.99 ( 41 )
# {'sweet paprika'}  ->  frozenset({'ground cumin'}) ; Rel =  74.42 ; Sup =  03.90 ( 32 )
# {'ground coriander'}  ->  frozenset({'ground cumin'}) ; Rel =  86.23 ; Sup =  14.49 ( 119 )
# {'yellow onion'}  ->  frozenset({'olive oil'}) ; Rel =  75.00 ; Sup =  04.38 ( 36 )
# {'green olives'}  ->  frozenset({'olive oil'}) ; Rel =  73.33 ; Sup =  04.02 ( 33 )
# {'ground red pepper'}  ->  frozenset({'ground cumin'}) ; Rel =  78.38 ; Sup =  03.53 ( 29 )
# british
# {'baking soda'}  ->  frozenset({'all-purpose flour'}) ; Rel =  75.34 ; Sup =  06.84 ( 55 )
# filipino
# {'tomatoes'}  ->  frozenset({'onions'}) ; Rel =  83.33 ; Sup =  05.96 ( 45 )
# {'potatoes'}  ->  frozenset({'onions'}) ; Rel =  84.00 ; Sup =  05.56 ( 42 )
# {'ginger'}  ->  frozenset({'garlic'}) ; Rel =  80.00 ; Sup =  06.89 ( 52 )
# {'cabbage'}  ->  frozenset({'carrots'}) ; Rel =  81.58 ; Sup =  04.11 ( 31 )
# {'red bell pepper'}  ->  frozenset({'onions'}) ; Rel =  70.00 ; Sup =  03.71 ( 28 )
# {'fish sauce'}  ->  frozenset({'onions'}) ; Rel =  71.43 ; Sup =  09.27 ( 70 )
# {'cabbage'}  ->  frozenset({'onions'}) ; Rel =  86.84 ; Sup =  04.37 ( 33 )
# {'olive oil'}  ->  frozenset({'garlic'}) ; Rel =  70.83 ; Sup =  04.50 ( 34 )
# {'lemon'}  ->  frozenset({'onions'}) ; Rel =  73.68 ; Sup =  03.71 ( 28 )
# {'black peppercorns'}  ->  frozenset({'bay leaves'}) ; Rel =  78.38 ; Sup =  03.84 ( 29 )
# {'black peppercorns'}  ->  frozenset({'soy sauce'}) ; Rel =  81.08 ; Sup =  03.97 ( 30 )
# {'red bell pepper'}  ->  frozenset({'garlic'}) ; Rel =  72.50 ; Sup =  03.84 ( 29 )
# {'bay leaves'}  ->  frozenset({'soy sauce'}) ; Rel =  72.16 ; Sup =  09.27 ( 70 )
# {'tomato sauce'}  ->  frozenset({'onions'}) ; Rel =  87.50 ; Sup =  03.71 ( 28 )
# irish
# {'buttermilk'}  ->  frozenset({'baking soda'}) ; Rel =  88.00 ; Sup =  09.90 ( 66 )
# {'cooking spray'}  ->  frozenset({'all-purpose flour'}) ; Rel =  72.92 ; Sup =  05.25 ( 35 )
# {'baking powder'}  ->  frozenset({'all-purpose flour'}) ; Rel =  85.71 ; Sup =  14.39 ( 96 )
# {'whole wheat flour'}  ->  frozenset({'all-purpose flour'}) ; Rel =  73.68 ; Sup =  04.20 ( 28 )
# {'large eggs'}  ->  frozenset({'all-purpose flour'}) ; Rel =  72.73 ; Sup =  08.40 ( 56 )
# {'baking soda'}  ->  frozenset({'all-purpose flour'}) ; Rel =  80.00 ; Sup =  13.79 ( 92 )
# {'whole wheat flour'}  ->  frozenset({'baking soda'}) ; Rel =  78.95 ; Sup =  04.50 ( 30 )
# jamaican
# {'tomatoes'}  ->  frozenset({'onions'}) ; Rel =  75.68 ; Sup =  05.32 ( 28 )
# russian
# {'garlic cloves'}  ->  frozenset({'onions'}) ; Rel =  74.42 ; Sup =  06.54 ( 32 )
# {'flour'}  ->  frozenset({'sugar'}) ; Rel =  72.13 ; Sup =  09.00 ( 44 )
# brazilian
# {'tomatoes'}  ->  frozenset({'onions'}) ; Rel =  74.60 ; Sup =  10.06 ( 47 )
